# %%
import handcalcs.render
import math as mt
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statistics as st
import CoolProp 
import CoolProp.CoolProp as CP
from CoolProp.CoolProp import Props
from CoolProp.CoolProp import PropsSI

# %% [markdown]
# DADOS DE ENTRADA

# %%
T_1=100 #°C-temperatura inferior
T_1_Abs=T_1+273.15
T_2=50 #°C-temperatura superior
T_2_Abs=T_2+273.15
T_p=60 #°C-temperatura da placa
T_p_Abs=T_p+273.15
T_a=20 #°C -temperatura do ar ambiente
T_a_Abs=T_a+273.15
epsilon_vidro=0.005 #m - espessura do vidro(borosilicato)
epsilon_placaevidro=0.02 #m-espaçamento entre a placa e a cobertura de vidro
epsilon_la= 0.03 #m-isolamento de ã de vidro
beta_vi= 30 #° -inclinação da placa 
g=9.81 #gravidade

# %% [markdown]
# DADOS TERMODINÂMICOS

# %%
k=30.0*10**-3 #W/mK 
beta_linha=2.874*10**-3 #K**-1
nu= 20.92*10**-6 #m**2/s
alpha = 29.9*10**-6 #m**2/s

# %% [markdown]
# Gcd=q_te+q_tr1+q_tc1+q_tk

# %% [markdown]
# Resistência Térmica Equivalente na Radiação

# %%
# %%render
# sigma=1
# epsilon_1=1
# epsilon_2=1
# A_2=1
# A_1=45
# F_12=1
# h_r= (sigma*(T_2_Abs**2+T_1_Abs**2)*(T_2_Abs+T_1_Abs))/(((1-epsilon_1)/epsilon_1)+(1/F_12)+((1-epsilon_2)*A_1)/(epsilon_2*A_2))
# R_T=1/h_r
# Out:
# \[
# \begin{aligned}
# \sigma &= 1 \;
# \\[10pt]
# \epsilon_{1} &= 1 \;
# \\[10pt]
# \epsilon_{2} &= 1 \;
# \\[10pt]
# A_{2} &= 1 \;
# \\[10pt]
# A_{1} &= 45 \;
# \\[10pt]
# F_{12} &= 1 \;
# \\[10pt]
# h_{r} &= \frac{ \sigma \cdot \left( \left( T_{2_{Abs}} \right) ^{ 2 } + \left( T_{1_{Abs}} \right) ^{ 2 } \right) \cdot \left( T_{2_{Abs}} + T_{1_{Abs}} \right) }{ \left( \frac{ 1 - \epsilon_{1} }{ \epsilon_{1} } \right) + \left( \frac{ 1 }{ F_{12} } \right) + \frac{ \left( 1 - \epsilon_{2} \right) \cdot A_{1} }{ \epsilon_{2} \cdot A_{2} } } \\&= \frac{ 1 \cdot \left( \left( 323.15 \right) ^{ 2 } + \left( 373.15 \right) ^{ 2 } \right) \cdot \left( 323.15 + 373.15 \right) }{ \left( \frac{ 1 - 1 }{ 1 } \right) + \left( \frac{ 1 }{ 1 } \right) + \frac{ \left( 1 - 1 \right) \cdot 45 }{ 1 \cdot 1 } } \\&= 169665224.173  \\
# \\[10pt]
# R_{T} &= 5.894 \times 10 ^ {-9 } \;
# \end{aligned}
# \]

# %%
beta_linha
# Out:
# 0.0028740000000000003

# %% [markdown]
# Numero de Prandt

# %%
Pr = nu / alpha

# %% [markdown]
# Numero de Grashof

# %%
L=epsilon_1
Gr= (g*L**3*beta_linha*(T_1_Abs-T_2_Abs))/nu

# %% [markdown]
# Numero de Rayleigh -espaçamento de 0.02

# %%
L=epsilon_2
Ra_1= (g*L**3*beta_linha*(T_1_Abs-T_2_Abs))/(nu*alpha)

# %% [markdown]
# Numero de Rayleigh -espaçamento de 0.02

# %%
epsilon_1
Ra_2= (g*L**3*beta_linha*(T_1_Abs-T_2_Abs))/(nu*alpha)

# %% [markdown]
# Numero de Holland

# %%
Nu_h_1= 1+1.44*(1-(1708)/(Ra_1*np.cos(np.radians(beta_vi))))*(1-(1708)/(Ra_1*np.cos(np.radians(beta_vi)))*np.sin(np.radians(beta_vi*1.8)**1.6))+((Ra_1*np.cos(np.radians(beta_vi))/5830)**(1/3)-1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-ebf203e7fb11> in <module>
# ----> 1 Nu_h_1= 1+1.44*(1-(1708)/(Ra_1*np.cos(np.radians(beta_vi))))*(1-(1708)/(Ra_1*np.cos(np.radians(beta_vi)))*np.sin(np.radians(beta_vi*1.8)**1.6))+((Ra_1*np.cos(np.radians(beta_vi))/5830)**(1/3)-1)
#
# NameError: name 'Ra_1' is not defined

# %% [markdown]
# Temperatura do ceu (SKY)

# %%
T_SKY_1=0.0552*T_a_Abs**1.5

# %%
# %%render
# T_dp=280.8
# T_SKY_2= T_a_Abs*(0.8+(T_dp-273)/250)**0.25
# Out:
# \[
# \begin{aligned}
# T_{dp} &= 280.8 \;
# \\[10pt]
# T_{SKY_{2}} &= T_{a_{Abs}} \cdot \left( 0.8 + \frac{ T_{dp} - 273 }{ 250 } \right) ^{ 0.25 }  = 293.15 \cdot \left( 0.8 + \frac{ 280.8 - 273 }{ 250 } \right) ^{ 0.25 } &= 279.909
# \end{aligned}
# \]

# %%
T_SKY=(T_SKY_1+T_SKY_2)/2

# %% [markdown]
# Análise Coletor Solar Plano

# %% [markdown]
# Placa - Vidro

# %%
# %%render
# T_v_Abs=1
# h_R1= (sigma*(T_p_Abs**2+T_v_Abs**2)*(T_p_Abs+T_v_Abs))/(((1-epsilon_placaevidro)/epsilon_placaevidro)+(1/F_12)+((1-epsilon_vidro))/(epsilon_vidro))
# RT_R1=1/h_R1
# Out:
# \[
# \begin{aligned}
# T_{v_{Abs}} &= 1 \;
# \\[10pt]
# h_{R1} &= \frac{ \sigma \cdot \left( \left( T_{p_{Abs}} \right) ^{ 2 } + \left( T_{v_{Abs}} \right) ^{ 2 } \right) \cdot \left( T_{p_{Abs}} + T_{v_{Abs}} \right) }{ \left( \frac{ 1 - \epsilon_{placaevidro} }{ \epsilon_{placaevidro} } \right) + \left( \frac{ 1 }{ F_{12} } \right) + \frac{ 1 - \epsilon_{vidro} }{ \epsilon_{vidro} } } \\&= \frac{ 1 \cdot \left( \left( 333.15 \right) ^{ 2 } + \left( 1 \right) ^{ 2 } \right) \cdot \left( 333.15 + 1 \right) }{ \left( \frac{ 1 - 0.02 }{ 0.02 } \right) + \left( \frac{ 1 }{ 1 } \right) + \frac{ 1 - 0.005 }{ 0.005 } } \\&= 148944.91  \\
# \\[10pt]
# \mathrm{RT}_{R1} &= 6.714 \times 10 ^ {-6 } \;
# \end{aligned}
# \]

# %% [markdown]
# Vidro - Céu

# %%
# %%render
# h_R2= epsilon_vidro*sigma*(T_SKY**2+T_v_Abs**2)*(T_SKY-T_v_Abs)
# RT_R2=1/h_R2
# Out:
# \[
# \begin{aligned}
# h_{R2} &= \epsilon_{vidro} \cdot \sigma \cdot \left( \left( T_{SKY} \right) ^{ 2 } + \left( T_{v_{Abs}} \right) ^{ 2 } \right) \cdot \left( T_{SKY} - T_{v_{Abs}} \right) \\&= 0.005 \cdot 1 \cdot \left( \left( 278.484 \right) ^{ 2 } + \left( 1 \right) ^{ 2 } \right) \cdot \left( 278.484 - 1 \right) \\&= 107600.839  \\
# \\[10pt]
# \mathrm{RT}_{R2} &= 9.294 \times 10 ^ {-6 } \;
# \end{aligned}
# \]
